# %%
from bilby.gw.detector.networks import load_interferometer

ifo = load_interferometer("ET_Sardinia.interferometer")

# %%
for sub_ifo in ifo:
    print(sub_ifo.name, sub_ifo.latitude, sub_ifo.longitude)
# Out:
# ET1 40.53277777777777 9.432777777777778
# ET2 40.46453805234988 9.491198986368902
# ET3 40.448063663357345 9.402891078164203
